# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mp
import matplotlib.pyplot as plt
import os

from datetime import datetime 

# !pip install download
from download import download

from __future__ import absolute_import, division, print_function, unicode_literals

mp.rcParams['figure.figsize'] = (8, 6)
mp.rcParams['axes.grid'] = False
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
date_files = download('https://archive.ics.uci.edu/ml/machine-learning-databases/00501/PRSA2017_Data_20130301-20170228.zip', '/tmp/aq', kind="zip")
# Out:
# Creating data folder...
# ...
#
# file_sizes: 100%|██████████████████████████| 7.96M/7.96M [00:00<00:00, 12.4MB/s]
# Extracting zip file...
# Successfully downloaded / unzipped to /tmp/aq

# %%
# !ls /tmp/aq/PRSA_Data_20130301-20170228
# Out:
# PRSA_Data_Aotizhongxin_20130301-20170228.csv
# PRSA_Data_Changping_20130301-20170228.csv
# PRSA_Data_Dingling_20130301-20170228.csv
# PRSA_Data_Dongsi_20130301-20170228.csv
# PRSA_Data_Guanyuan_20130301-20170228.csv
# PRSA_Data_Gucheng_20130301-20170228.csv
# PRSA_Data_Huairou_20130301-20170228.csv
# PRSA_Data_Nongzhanguan_20130301-20170228.csv
# PRSA_Data_Shunyi_20130301-20170228.csv
# PRSA_Data_Tiantan_20130301-20170228.csv
# PRSA_Data_Wanliu_20130301-20170228.csv
# PRSA_Data_Wanshouxigong_20130301-20170228.csv

# %%
df = pd.read_csv('/tmp/aq/PRSA_Data_20130301-20170228/PRSA_Data_Dingling_20130301-20170228.csv', encoding='ISO-8859-1')

# %%
df
# Out:
#           No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO     O3  \
# 0          1  2013      3    1     0    4.0   4.0  3.0  NaN  200.0   82.0
# 1          2  2013      3    1     1    7.0   7.0  3.0  NaN  200.0   80.0
# 2          3  2013      3    1     2    5.0   5.0  3.0  2.0  200.0   79.0
# 3          4  2013      3    1     3    6.0   6.0  3.0  NaN  200.0   79.0
# 4          5  2013      3    1     4    5.0   5.0  3.0  NaN  200.0   81.0
# ...      ...   ...    ...  ...   ...    ...   ...  ...  ...    ...    ...
# 35059  35060  2017      2   28    19   11.0  11.0  2.0  2.0  200.0   99.0
# 35060  35061  2017      2   28    20   13.0  13.0  2.0  2.0  200.0  101.0
# 35061  35062  2017      2   28    21    9.0  14.0  2.0  2.0  200.0  102.0
# 35062  35063  2017      2   28    22   10.0  12.0  2.0  2.0  200.0   97.0
# 35063  35064  2017      2   28    23   13.0  16.0  4.0  9.0  500.0   74.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM   station
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34285 non-null  float64
#  6   PM10     34408 non-null  float64
#  7   SO2      34334 non-null  float64
#  8   NO2      33830 non-null  float64
#  9   CO       33052 non-null  float64
#  10  O3       33850 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
def date_converter(x):
	return datetime.strptime(x, '%Y %m %d %H')

# %%
new_df = pd.read_csv('/tmp/aq/PRSA_Data_20130301-20170228/PRSA_Data_Dingling_20130301-20170228.csv', parse_dates = [['year', 'month', 'day', 'hour']],date_parser=date_converter, keep_date_col=True)

# %%
new_df.head()
# Out:
#   year_month_day_hour  No  year month day hour  PM2.5  PM10  SO2  NO2     CO  \
# 0 2013-03-01 00:00:00   1  2013     3   1    0    4.0   4.0  3.0  NaN  200.0
# 1 2013-03-01 01:00:00   2  2013     3   1    1    7.0   7.0  3.0  NaN  200.0
# 2 2013-03-01 02:00:00   3  2013     3   1    2    5.0   5.0  3.0  2.0  200.0
# 3 2013-03-01 03:00:00   4  2013     3   1    3    6.0   6.0  3.0  NaN  200.0
# 4 2013-03-01 04:00:00   5  2013     3   1    4    5.0   5.0  3.0  NaN  200.0
#
#      O3  TEMP    PRES  DEWP  RAIN   wd  WSPM   station
# 0  82.0  -2.3  1020.8 -19.7   0.0    E   0.5  Dingling
# 1  80.0  -2.5  1021.3 -19.0   0.0  ENE   0.7  Dingling
# 2  79.0  -3.0  1021.3 -19.9   0.0  ENE   0.2  Dingling
# 3  79.0  -3.6  1021.8 -19.1   0.0  NNE   1.0  Dingling
# 4  81.0  -3.5  1022.3 -19.4   0.0    N   2.1  Dingling

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   year_month_day_hour  35064 non-null  datetime64[ns]
#  1   No                   35064 non-null  int64
#  2   year                 35064 non-null  object
#  3   month                35064 non-null  object
#  4   day                  35064 non-null  object
#  5   hour                 35064 non-null  object
#  6   PM2.5                34285 non-null  float64
#  7   PM10                 34408 non-null  float64
#  8   SO2                  34334 non-null  float64
#  9   NO2                  33830 non-null  float64
#  10  CO                   33052 non-null  float64
#  11  O3                   33850 non-null  float64
#  12  TEMP                 35011 non-null  float64
#  13  PRES                 35014 non-null  float64
#  14  DEWP                 35011 non-null  float64
# ...

# %%
#converting month column to numeric
new_df['month']=pd.to_numeric(new_df['month'])

# %%
print ("Rows     : " ,new_df.shape[0])
print ("Columns  : " ,new_df.shape[1])
# Out:
# Rows     :  35064
# Columns  :  19

# %%
print ("\nFeatures : \n" ,new_df.columns.tolist())
print ("\nMissing values :  ", new_df.isnull().any())
print ("\nUnique values :  \n",new_df.nunique())
# Out:
# Features :
#  ['year_month_day_hour', 'No', 'year', 'month', 'day', 'hour', 'PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM', 'station']
#
# Missing values :   year_month_day_hour    False
# No                     False
# year                   False
# month                  False
# day                    False
# hour                   False
# PM2.5                   True
# PM10                    True
# SO2                     True
# NO2                     True
# CO                      True
# O3                      True
# TEMP                    True
# PRES                    True
# DEWP                    True
# RAIN                    True
# wd                      True
# WSPM                    True
# station                False
# dtype: bool
#
# Unique values :
#  year_month_day_hour    35064
# No                     35064
# year                       5
# month                     12
# day                       31
# ...

# %%
new_df.describe()
# Out:
#                  No         month         PM2.5          PM10           SO2  \
# count  35064.000000  35064.000000  34285.000000  34408.000000  34334.000000
# mean   17532.500000      6.522930     65.989497     83.739723     11.749650
# std    10122.249256      3.448752     72.267723     79.541685     15.519259
# min        1.000000      1.000000      3.000000      2.000000      0.285600
# 25%     8766.750000      4.000000     14.000000     26.000000      2.000000
# 50%    17532.500000      7.000000     41.000000     60.000000      5.000000
# 75%    26298.250000     10.000000     93.000000    117.000000     15.000000
# max    35064.000000     12.000000    881.000000    905.000000    156.000000
#
#                 NO2            CO            O3          TEMP          PRES  \
# count  33830.000000  33052.000000  33850.000000  35011.000000  35014.000000
# mean      27.585467    904.896073     68.548371     13.686111   1007.760278
# ...

# %%
new_df_non_indexed=new_df.copy()

# %%
new_df = new_df.set_index('year_month_day_hour')

# %%
new_df.index
# Out:
# DatetimeIndex(['2013-03-01 00:00:00', '2013-03-01 01:00:00',
#                '2013-03-01 02:00:00', '2013-03-01 03:00:00',
#                '2013-03-01 04:00:00', '2013-03-01 05:00:00',
#                '2013-03-01 06:00:00', '2013-03-01 07:00:00',
#                '2013-03-01 08:00:00', '2013-03-01 09:00:00',
#                ...
#                '2017-02-28 14:00:00', '2017-02-28 15:00:00',
#                '2017-02-28 16:00:00', '2017-02-28 17:00:00',
#                '2017-02-28 18:00:00', '2017-02-28 19:00:00',
#                '2017-02-28 20:00:00', '2017-02-28 21:00:00',
#                '2017-02-28 22:00:00', '2017-02-28 23:00:00'],
#               dtype='datetime64[ns]', name='year_month_day_hour', length=35064, freq=None)

# %%
new_df.head()
# Out:
#                      No  year  month day hour  PM2.5  PM10  SO2  NO2     CO  \
# year_month_day_hour
# 2013-03-01 00:00:00   1  2013      3   1    0    4.0   4.0  3.0  NaN  200.0
# 2013-03-01 01:00:00   2  2013      3   1    1    7.0   7.0  3.0  NaN  200.0
# 2013-03-01 02:00:00   3  2013      3   1    2    5.0   5.0  3.0  2.0  200.0
# 2013-03-01 03:00:00   4  2013      3   1    3    6.0   6.0  3.0  NaN  200.0
# 2013-03-01 04:00:00   5  2013      3   1    4    5.0   5.0  3.0  NaN  200.0
#
#                        O3  TEMP    PRES  DEWP  RAIN   wd  WSPM   station
# year_month_day_hour
# 2013-03-01 00:00:00  82.0  -2.3  1020.8 -19.7   0.0    E   0.5  Dingling
# 2013-03-01 01:00:00  80.0  -2.5  1021.3 -19.0   0.0  ENE   0.7  Dingling
# 2013-03-01 02:00:00  79.0  -3.0  1021.3 -19.9   0.0  ENE   0.2  Dingling
# 2013-03-01 03:00:00  79.0  -3.6  1021.8 -19.1   0.0  NNE   1.0  Dingling
# 2013-03-01 04:00:00  81.0  -3.5  1022.3 -19.4   0.0    N   2.1  Dingling

# %%
new_df.loc['2013-03-01':'2013-03-05']
# Out:
#                       No  year  month day hour  PM2.5   PM10   SO2   NO2  \
# year_month_day_hour
# 2013-03-01 00:00:00    1  2013      3   1    0    4.0    4.0   3.0   NaN
# 2013-03-01 01:00:00    2  2013      3   1    1    7.0    7.0   3.0   NaN
# 2013-03-01 02:00:00    3  2013      3   1    2    5.0    5.0   3.0   2.0
# 2013-03-01 03:00:00    4  2013      3   1    3    6.0    6.0   3.0   NaN
# 2013-03-01 04:00:00    5  2013      3   1    4    5.0    5.0   3.0   NaN
# ...                  ...   ...    ...  ..  ...    ...    ...   ...   ...
# 2013-03-05 19:00:00  116  2013      3   5   19  179.0  200.0  50.0  96.0
# 2013-03-05 20:00:00  117  2013      3   5   20  172.0  180.0  43.0  94.0
# 2013-03-05 21:00:00  118  2013      3   5   21  179.0  191.0  38.0  80.0
# 2013-03-05 22:00:00  119  2013      3   5   22  173.0  168.0  39.0  73.0
# 2013-03-05 23:00:00  120  2013      3   5   23  170.0  162.0  42.0  72.0
#
# ...

# %%
new_df.loc['2013':'2015']
# Out:
#                         No  year  month day hour  PM2.5   PM10   SO2   NO2  \
# year_month_day_hour
# 2013-03-01 00:00:00      1  2013      3   1    0    4.0    4.0   3.0   NaN
# 2013-03-01 01:00:00      2  2013      3   1    1    7.0    7.0   3.0   NaN
# 2013-03-01 02:00:00      3  2013      3   1    2    5.0    5.0   3.0   2.0
# 2013-03-01 03:00:00      4  2013      3   1    3    6.0    6.0   3.0   NaN
# 2013-03-01 04:00:00      5  2013      3   1    4    5.0    5.0   3.0   NaN
# ...                    ...   ...    ...  ..  ...    ...    ...   ...   ...
# 2015-12-31 19:00:00  24860  2015     12  31   19   85.0   95.0  12.0  73.0
# 2015-12-31 20:00:00  24861  2015     12  31   20    NaN  109.0  32.0  79.0
# 2015-12-31 21:00:00  24862  2015     12  31   21   80.0  100.0  35.0  81.0
# 2015-12-31 22:00:00  24863  2015     12  31   22   93.0   93.0  28.0  76.0
# 2015-12-31 23:00:00  24864  2015     12  31   23   98.0   98.0  25.0  75.0
#
# ...

# %%
pm_data = new_df['PM2.5']
pm_data.head()
# Out:
# year_month_day_hour
# 2013-03-01 00:00:00    4.0
# 2013-03-01 01:00:00    7.0
# 2013-03-01 02:00:00    5.0
# 2013-03-01 03:00:00    6.0
# 2013-03-01 04:00:00    5.0
# Name: PM2.5, dtype: float64

# %%
pm_data.plot(grid=True)

# %%
new_df_2015=new_df.loc['2015']
pm_data_2015=new_df_2015['PM2.5']
pm_data_2015.plot(grid=True)

# %%
new_df_2016=new_df['2016']
pm_data_2016=new_df_2016['PM2.5']
pm_data_2016.plot(grid=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   """Entry point for launching an IPython kernel.

# %%
import plotly.express as px
fig = px.line(new_df_non_indexed, x='year_month_day_hour', y='PM2.5', title='PM2.5 with Slider')

fig.update_xaxes(rangeslider_visible=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(new_df_non_indexed, x='year_month_day_hour', y='PM2.5', title='PM2.5 with Slider')

fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(count=2, label="2y", step="year", stepmode="backward"),
            dict(count=3, label="3y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    )
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_2014= new_df['2014'].reset_index()
df_2015 = new_df['2015'].reset_index()
df_2014['month_day_hour']=df_2014.apply(lambda x : str(x['month'])+"-"+x['day'],axis=1)
df_2015['month_day_hour']=df_2015.apply(lambda x : str(x['month'])+"-"+x['day'],axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning:
#
# Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning:
#
# Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.

# %%
plt.plot(df_2014['month_day_hour'], df_2014['PM2.5'])
plt.plot(df_2015['month_day_hour'], df_2015['PM2.5'])
plt.legend(['2014', '2015'])
plt.xlabel('Month')
plt.ylabel('PM2.5')
plt.title('Air Quality plot for the year 2014 and 2015')
# Out:
# Text(0.5, 1.0, 'Air Quality plot for the year 2014 and 2015')

# %%
new_df['2014':'2016'][['month','PM2.5']]
# Out:
#                      month  PM2.5
# year_month_day_hour
# 2014-01-01 00:00:00      1   27.0
# 2014-01-01 01:00:00      1   25.0
# 2014-01-01 02:00:00      1   27.0
# 2014-01-01 03:00:00      1   34.0
# 2014-01-01 04:00:00      1   32.0
# ...                    ...    ...
# 2016-12-31 19:00:00     12  251.0
# 2016-12-31 20:00:00     12  256.0
# 2016-12-31 21:00:00     12  232.0
# 2016-12-31 22:00:00     12  208.0
# 2016-12-31 23:00:00     12  204.0
#
# [26304 rows x 2 columns]

# %%
#monthwise describe()
new_df['2014':'2016'][['month','PM2.5']].groupby('month').describe()
# Out:
#         PM2.5
#         count       mean         std  min   25%   50%     75%    max
# month
# 1      2173.0  70.285274   75.913587  3.0  12.0  38.0  113.00  443.0
# 2      1978.0  86.389282  105.603069  3.0  10.0  33.0  132.00  881.0
# 3      2212.0  80.193852   87.889440  3.0  13.0  47.0  123.25  474.0
# 4      2105.0  67.963325   56.430235  3.0  25.0  54.0   95.00  346.0
# 5      2188.0  47.994378   44.843130  3.0  16.0  35.0   67.00  358.0
# 6      2119.0  46.655403   43.877349  3.0  13.0  31.0   69.00  245.0
# 7      2205.0  61.671474   50.926149  3.0  21.0  48.0   91.00  252.0
# 8      2206.0  41.364869   37.279312  3.0  13.0  29.0   60.00  217.0
# 9      2074.0  45.356123   43.235331  3.0  11.0  27.0   78.00  240.0
# 10     2081.0  82.586257   92.234361  3.0  13.0  43.0  124.00  414.0
# 11     2141.0  77.500140   71.720648  3.0  20.0  56.0  112.00  394.0
# 12     2186.0  87.990851  104.677021  3.0  11.0  48.5  135.00  647.0

# %%
# agg() function 
new_df['2014':'2016'][['month','PM2.5','TEMP']].groupby('month').agg({'PM2.5':['max'],'TEMP':['min','max']})
# Out:
#        PM2.5  TEMP
#          max   min   max
# month
# 1      443.0 -16.6  12.4
# 2      881.0 -10.9  14.0
# 3      474.0  -6.4  26.0
# 4      346.0   1.3  32.0
# 5      358.0   7.0  41.4
# 6      245.0  15.1  38.1
# 7      252.0  16.8  39.2
# 8      217.0  16.6  36.3
# 9      240.0   7.8  34.5
# 10     414.0  -1.4  28.1
# 11     394.0 -10.3  20.8
# 12     647.0  -9.7  11.6

# %%
new_df_2015=new_df['2015']
pm_data_2015=new_df_2015[['PM2.5','TEMP']]
pm_data_2015.plot(subplots=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning:
#
# Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fa270c8b550>,
# ...
#       dtype=object)

# %%
new_df[['PM2.5','TEMP']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa2708832d0>,
# ...
#       dtype=object)

# %%
new_df[['TEMP']].plot(kind='density')

# %%
#lag_plot() when lag = 1 (1 hour)
pd.plotting.lag_plot(new_df['TEMP'],lag=1)

# %%
#lag_plot() when lag = 10 (10 hour)
pd.plotting.lag_plot(new_df['TEMP'],lag=10)

# %%
#lag_plot() when lag = 24 (1 day)
pd.plotting.lag_plot(new_df['TEMP'],lag=24)

# %%
#lag_plot() when lag = 8640 (1 year)
pd.plotting.lag_plot(new_df['TEMP'],lag=8640)

# %%
pd.plotting.lag_plot(new_df['TEMP'],lag=4320) # (lag = 6 months)

# %%
pd.plotting.lag_plot(new_df['TEMP'],lag=2150) # (lag = 3 months )

# %%
new_df_2015=new_df['2015']
pm_data_2015=new_df_2015[['PM2.5','TEMP','PRES']]
pm_data_2015.plot(subplots=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning:
#
# Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fa26cff5750>,
# ...
#       dtype=object)

# %%
multi_data = new_df[['TEMP','PRES','DEWP', 'RAIN','PM2.5']]
multi_data.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fa26c98fb50>,
# ...
#       dtype=object)

# %%
multi_data = new_df[['SO2','NO2','O3', 'CO','PM2.5']]
multi_data.plot(figsize=(15,8), subplots=True,linewidth=3, fontsize=10)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fa2699777d0>,
# ...
#       dtype=object)

# %%
new_df['2014':'2015'][['PM2.5','O3']].plot(figsize=(15,8), linewidth=3, fontsize=10)
plt.xlabel('year_month_day_hour', fontsize=15);

# %%
new_df_2015
# Out:
#                         No  year  month day  ... RAIN   wd  WSPM   station
# year_month_day_hour                          ...
# 2015-01-01 00:00:00  16105  2015      1   1  ...  0.0   NW   3.3  Dingling
# 2015-01-01 01:00:00  16106  2015      1   1  ...  0.0  NNE   1.2  Dingling
# 2015-01-01 02:00:00  16107  2015      1   1  ...  0.0  NNW   1.7  Dingling
# 2015-01-01 03:00:00  16108  2015      1   1  ...  0.0    N   1.7  Dingling
# 2015-01-01 04:00:00  16109  2015      1   1  ...  0.0   NE   1.8  Dingling
# ...                    ...   ...    ...  ..  ...  ...  ...   ...       ...
# 2015-12-31 19:00:00  24860  2015     12  31  ...  0.0   NE   0.6  Dingling
# 2015-12-31 20:00:00  24861  2015     12  31  ...  0.0   NW   1.1  Dingling
# 2015-12-31 21:00:00  24862  2015     12  31  ...  0.0   NE   0.9  Dingling
# 2015-12-31 22:00:00  24863  2015     12  31  ...  0.0  NNW   1.3  Dingling
# 2015-12-31 23:00:00  24864  2015     12  31  ...  0.0  NNW   1.3  Dingling
#
# ...

# %%
new_df_2015['PM2.5']
# Out:
# year_month_day_hour
# 2015-01-01 00:00:00     NaN
# 2015-01-01 01:00:00     NaN
# 2015-01-01 02:00:00     NaN
# 2015-01-01 03:00:00     NaN
# 2015-01-01 04:00:00     NaN
#                        ...
# 2015-12-31 19:00:00    85.0
# 2015-12-31 20:00:00     NaN
# 2015-12-31 21:00:00    80.0
# 2015-12-31 22:00:00    93.0
# 2015-12-31 23:00:00    98.0
# Name: PM2.5, Length: 8760, dtype: float64

# %%
new_df.isnull().values.any()
# Out:
# True

# %%
new_df.isnull().any()
# Out:
# No         False
# year       False
# month      False
# day        False
# hour       False
# PM2.5       True
# PM10        True
# SO2         True
# NO2         True
# CO          True
# O3          True
# TEMP        True
# PRES        True
# DEWP        True
# RAIN        True
# wd          True
# WSPM        True
# station    False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       779
# PM10        656
# SO2         730
# NO2        1234
# CO         2012
# O3         1214
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
g = sns.pairplot(new_df[['SO2','NO2','O3', 'CO','PM2.5']])

# %%
aq_corr=new_df[['SO2','NO2','O3', 'CO','PM2.5']].corr(method='pearson')
aq_corr
# Out:
#             SO2       NO2        O3        CO     PM2.5
# SO2    1.000000  0.610433 -0.182096  0.529182  0.475117
# NO2    0.610433  1.000000 -0.373625  0.798753  0.718170
# O3    -0.182096 -0.373625  1.000000 -0.303275 -0.100542
# CO     0.529182  0.798753 -0.303275  1.000000  0.802737
# PM2.5  0.475117  0.718170 -0.100542  0.802737  1.000000

# %%
heat = sns.heatmap(aq_corr,  vmax=.6, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True, fmt='.2f', cmap='coolwarm')
heat.figure.set_size_inches(10,10)
    
plt.show()

# %%
new_df.groupby('wd').agg(median=('PM2.5','median'),mean=('PM2.5','mean'),max=('PM2.5','max'), min=('PM2.5','min')).reset_index()
# Out:
#      wd  median       mean    max  min
# 0     E    70.0  88.623363  434.0  3.0
# 1   ENE    56.5  77.685514  647.0  3.0
# 2   ESE    78.5  96.492276  632.0  3.0
# 3     N    29.0  57.546221  536.0  3.0
# 4    NE    32.0  57.390083  530.0  3.0
# 5   NNE    26.0  53.946239  881.0  3.0
# 6   NNW    33.0  62.790775  548.0  3.0
# 7    NW    21.0  52.769116  535.0  3.0
# 8     S    52.0  72.497281  511.0  3.0
# 9    SE    70.0  85.045709  617.0  3.0
# 10  SSE    61.0  79.925967  614.0  3.0
# 11  SSW    50.0  73.078253  493.0  3.0
# 12   SW    46.0  70.233140  459.0  3.0
# 13    W    22.0  49.488104  446.0  3.0
# 14  WNW    14.0  37.307447  515.0  3.0
# 15  WSW    39.0  66.725926  451.0  3.0

# %%
new_df_na = new_df.copy()
new_df_na=new_df_na.dropna()

# %%
# autocorrelation plot

pd.plotting.autocorrelation_plot(new_df_na['2014':'2016']['TEMP'])

# %%
new_df_na['TEMP'].resample("1m").mean()
# Out:
# year_month_day_hour
# 2013-03-31     6.039970
# 2013-04-30    12.208494
# 2013-05-31    21.886386
# 2013-06-30    23.752827
# 2013-07-31    27.405079
# 2013-08-31    27.228465
# 2013-09-30    20.482500
# 2013-10-31          NaN
# 2013-11-30     5.434524
# 2013-12-31     0.896623
# 2014-01-31     0.023428
# 2014-02-28    -0.352762
# 2014-03-31    10.415449
# 2014-04-30    17.235362
# 2014-05-31    22.043236
# 2014-06-30    25.194985
# 2014-07-31    28.409502
# 2014-08-31    26.284552
# 2014-09-30    20.834161
# 2014-10-31    13.556000
# 2014-11-30     6.357762
# 2014-12-31    -0.745582
# 2015-01-31    -0.590377
# 2015-02-28     1.572512
# 2015-03-31     8.707613
# 2015-04-30    15.566570
# 2015-05-31    21.300275
# 2015-06-30    24.636691
# 2015-07-31    26.228630
# 2015-08-31    26.135854
# 2015-09-30    20.392206
# 2015-10-31    14.387465
# 2015-11-30     3.358686
# 2015-12-31    -0.053912
# 2016-01-31    -4.233428
# 2016-02-29     1.434441
# 2016-03-31     8.687006
# ...

# %%
pd.plotting.autocorrelation_plot(new_df_na['2014':'2016']['TEMP'].resample("1m").mean())

# %%
pd.plotting.autocorrelation_plot(new_df_na['2014':'2016']['PM2.5'].resample("1m").mean())
